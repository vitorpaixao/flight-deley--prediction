# %% [markdown]
# # (ETL) Extração, Transformação e Carregamento dos Dados
#
# Este notebook lê os CSVs brutos, aplica todas as transformações de limpeza e exporta o resultado em Parquet para uso nos notebooks de análise e modelagem.
#
# **Pipeline:**
# 1. Joins com airlines e airports
# 2. Remoção de colunas sem valor preditivo
# 3. Remoção de voos cancelados
# 4. Tratamento de NaN nas causas de atraso
# 5. Remoção de registros sem DEPARTURE_DELAY
# 6. Tratamento de NaN nas colunas de join
# 7. Feature engineering
# 8. Exportação em Parquet

# %% [markdown]
# # Extração
#
# 1. Joins com airlines e airports

# %%
import pandas as pd
import numpy as np

pd.set_option('display.max_columns', None)

# %%
import os
os.makedirs("../plan/outputs", exist_ok=True)

flights = pd.read_csv("../data/flights.csv", low_memory=False)
airports = pd.read_csv("../data/airports.csv")
airlines = pd.read_csv("../data/airlines.csv")

print(flights.head(5))
with open("../plan/outputs/flights_head.txt", "w") as f:
    print(flights.head(5), file=f)

print(airports.head(5))
with open("../plan/outputs/airports_head.txt", "w") as f:
    print(airports.head(5), file=f)

print(airlines.head(5))
with open("../plan/outputs/airlines_head.txt", "w") as f:
    print(airlines.head(5), file=f)
# Out:
#    YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER TAIL_NUMBER  \
# 0  2015      1    1            4      AS             98      N407AS
# 1  2015      1    1            4      AA           2336      N3KUAA
# 2  2015      1    1            4      US            840      N171US
# 3  2015      1    1            4      AA            258      N3HYAA
# 4  2015      1    1            4      AS            135      N527AS
#
#   ORIGIN_AIRPORT DESTINATION_AIRPORT  SCHEDULED_DEPARTURE  DEPARTURE_TIME  \
# 0            ANC                 SEA                    5          2354.0
# 1            LAX                 PBI                   10             2.0
# 2            SFO                 CLT                   20            18.0
# 3            LAX                 MIA                   20            15.0
# 4            SEA                 ANC                   25            24.0
#
#    DEPARTURE_DELAY  TAXI_OUT  WHEELS_OFF  SCHEDULED_TIME  ELAPSED_TIME  \
# 0            -11.0      21.0        15.0           205.0         194.0
# 1             -8.0      12.0        14.0           280.0         279.0
# 2             -2.0      16.0        34.0           286.0         293.0
# 3             -5.0      15.0        30.0           285.0         281.0
# 4             -1.0      11.0        35.0           235.0         215.0
#
#    AIR_TIME  DISTANCE  WHEELS_ON  TAXI_IN  SCHEDULED_ARRIVAL  ARRIVAL_TIME  \
# 0     169.0      1448      404.0      4.0                430         408.0
# 1     263.0      2330      737.0      4.0                750         741.0
# 2     266.0      2296      800.0     11.0                806         811.0
# 3     258.0      2342      748.0      8.0                805         756.0
# 4     199.0      1448      254.0      5.0                320         259.0
#
#    ARRIVAL_DELAY  DIVERTED  CANCELLED CANCELLATION_REASON  AIR_SYSTEM_DELAY  \
# 0          -22.0         0          0                 NaN               NaN
# 1           -9.0         0          0                 NaN               NaN
# 2            5.0         0          0                 NaN               NaN
# 3           -9.0         0          0                 NaN               NaN
# 4          -21.0         0          0                 NaN               NaN
#
#    SECURITY_DELAY  AIRLINE_DELAY  LATE_AIRCRAFT_DELAY  WEATHER_DELAY
# 0             NaN            NaN                  NaN            NaN
# 1             NaN            NaN                  NaN            NaN
# 2             NaN            NaN                  NaN            NaN
# 3             NaN            NaN                  NaN            NaN
# 4             NaN            NaN                  NaN            NaN
#   IATA_CODE                              AIRPORT         CITY STATE COUNTRY  \
# 0       ABE  Lehigh Valley International Airport    Allentown    PA     USA
# 1       ABI             Abilene Regional Airport      Abilene    TX     USA
# 2       ABQ    Albuquerque International Sunport  Albuquerque    NM     USA
# 3       ABR            Aberdeen Regional Airport     Aberdeen    SD     USA
# 4       ABY   Southwest Georgia Regional Airport       Albany    GA     USA
#
#    LATITUDE  LONGITUDE
# 0  40.65236  -75.44040
# 1  32.41132  -99.68190
# 2  35.04022 -106.60919
# 3  45.44906  -98.42183
# 4  31.53552  -84.19447
#   IATA_CODE                 AIRLINE
# 0        UA   United Air Lines Inc.
# 1        AA  American Airlines Inc.
# 2        US         US Airways Inc.
# 3        F9  Frontier Airlines Inc.
# 4        B6         JetBlue Airways

# %%
# Join airlines
flights = flights.merge(airlines, left_on="AIRLINE", right_on="IATA_CODE", how="left") \
                 .drop(columns="IATA_CODE") \
                 .rename(columns={"AIRLINE_y": "AIRLINE_NAME", "AIRLINE_x": "AIRLINE"})

# Join airports — ORIGIN
flights = flights.merge(airports, left_on="ORIGIN_AIRPORT", right_on="IATA_CODE", how="left") \
                 .drop(columns="IATA_CODE") \
                 .rename(columns={
                     "AIRPORT": "ORIGIN_AIRPORT_NAME",
                     "CITY": "ORIGIN_CITY",
                     "STATE": "ORIGIN_STATE",
                     "LATITUDE": "ORIGIN_LAT",
                     "LONGITUDE": "ORIGIN_LON"
                 }).drop(columns=["COUNTRY"])

# Join airports — DESTINATION
flights = flights.merge(airports, left_on="DESTINATION_AIRPORT", right_on="IATA_CODE", how="left") \
                 .drop(columns="IATA_CODE") \
                 .rename(columns={
                     "AIRPORT": "DEST_AIRPORT_NAME",
                     "CITY": "DEST_CITY",
                     "STATE": "DEST_STATE",
                     "LATITUDE": "DEST_LAT",
                     "LONGITUDE": "DEST_LON"
                 }).drop(columns=["COUNTRY"])

print(f"Shape inicial (após joins): {flights.shape}")

print(flights.head(5))
print(flights.head(5))
with open("../plan/outputs/flights_joined.txt", "w") as f:
    print(flights.head(5), file=f)
# Out:
# Shape inicial (após joins): (5819079, 42)
#    YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER TAIL_NUMBER  \
# 0  2015      1    1            4      AS             98      N407AS
# 1  2015      1    1            4      AA           2336      N3KUAA
# 2  2015      1    1            4      US            840      N171US
# 3  2015      1    1            4      AA            258      N3HYAA
# 4  2015      1    1            4      AS            135      N527AS
#
#   ORIGIN_AIRPORT DESTINATION_AIRPORT  SCHEDULED_DEPARTURE  DEPARTURE_TIME  \
# 0            ANC                 SEA                    5          2354.0
# 1            LAX                 PBI                   10             2.0
# 2            SFO                 CLT                   20            18.0
# 3            LAX                 MIA                   20            15.0
# 4            SEA                 ANC                   25            24.0
#
#    DEPARTURE_DELAY  TAXI_OUT  WHEELS_OFF  SCHEDULED_TIME  ELAPSED_TIME  \
# 0            -11.0      21.0        15.0           205.0         194.0
# 1             -8.0      12.0        14.0           280.0         279.0
# 2             -2.0      16.0        34.0           286.0         293.0
# 3             -5.0      15.0        30.0           285.0         281.0
# 4             -1.0      11.0        35.0           235.0         215.0
#
#    AIR_TIME  DISTANCE  WHEELS_ON  TAXI_IN  SCHEDULED_ARRIVAL  ARRIVAL_TIME  \
# 0     169.0      1448      404.0      4.0                430         408.0
# 1     263.0      2330      737.0      4.0                750         741.0
# 2     266.0      2296      800.0     11.0                806         811.0
# 3     258.0      2342      748.0      8.0                805         756.0
# 4     199.0      1448      254.0      5.0                320         259.0
#
#    ARRIVAL_DELAY  DIVERTED  CANCELLED CANCELLATION_REASON  AIR_SYSTEM_DELAY  \
# 0          -22.0         0          0                 NaN               NaN
# 1           -9.0         0          0                 NaN               NaN
# 2            5.0         0          0                 NaN               NaN
# 3           -9.0         0          0                 NaN               NaN
# 4          -21.0         0          0                 NaN               NaN
#
#    SECURITY_DELAY  AIRLINE_DELAY  LATE_AIRCRAFT_DELAY  WEATHER_DELAY  \
# 0             NaN            NaN                  NaN            NaN
# 1             NaN            NaN                  NaN            NaN
# 2             NaN            NaN                  NaN            NaN
# 3             NaN            NaN                  NaN            NaN
# 4             NaN            NaN                  NaN            NaN
#
#              AIRLINE_NAME                          ORIGIN_AIRPORT_NAME  \
# 0    Alaska Airlines Inc.  Ted Stevens Anchorage International Airport
# 1  American Airlines Inc.            Los Angeles International Airport
# 2         US Airways Inc.          San Francisco International Airport
# 3  American Airlines Inc.            Los Angeles International Airport
# 4    Alaska Airlines Inc.         Seattle-Tacoma International Airport
#
#      ORIGIN_CITY ORIGIN_STATE  ORIGIN_LAT  ORIGIN_LON  \
# 0      Anchorage           AK    61.17432  -149.99619
# 1    Los Angeles           CA    33.94254  -118.40807
# 2  San Francisco           CA    37.61900  -122.37484
# 3    Los Angeles           CA    33.94254  -118.40807
# 4        Seattle           WA    47.44898  -122.30931
#
#                              DEST_AIRPORT_NAME        DEST_CITY DEST_STATE  \
# 0         Seattle-Tacoma International Airport          Seattle         WA
# 1             Palm Beach International Airport  West Palm Beach         FL
# 2      Charlotte Douglas International Airport        Charlotte         NC
# 3                  Miami International Airport            Miami         FL
# 4  Ted Stevens Anchorage International Airport        Anchorage         AK
#
#    DEST_LAT   DEST_LON
# 0  47.44898 -122.30931
# 1  26.68316  -80.09559
# 2  35.21401  -80.94313
# 3  25.79325  -80.29056
# 4  61.17432 -149.99619
#    YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER TAIL_NUMBER  \
# 0  2015      1    1            4      AS             98      N407AS
# 1  2015      1    1            4      AA           2336      N3KUAA
# 2  2015      1    1            4      US            840      N171US
# 3  2015      1    1            4      AA            258      N3HYAA
# 4  2015      1    1            4      AS            135      N527AS
#
#   ORIGIN_AIRPORT DESTINATION_AIRPORT  SCHEDULED_DEPARTURE  DEPARTURE_TIME  \
# 0            ANC                 SEA                    5          2354.0
# 1            LAX                 PBI                   10             2.0
# 2            SFO                 CLT                   20            18.0
# 3            LAX                 MIA                   20            15.0
# 4            SEA                 ANC                   25            24.0
#
#    DEPARTURE_DELAY  TAXI_OUT  WHEELS_OFF  SCHEDULED_TIME  ELAPSED_TIME  \
# 0            -11.0      21.0        15.0           205.0         194.0
# 1             -8.0      12.0        14.0           280.0         279.0
# 2             -2.0      16.0        34.0           286.0         293.0
# 3             -5.0      15.0        30.0           285.0         281.0
# 4             -1.0      11.0        35.0           235.0         215.0
#
#    AIR_TIME  DISTANCE  WHEELS_ON  TAXI_IN  SCHEDULED_ARRIVAL  ARRIVAL_TIME  \
# 0     169.0      1448      404.0      4.0                430         408.0
# 1     263.0      2330      737.0      4.0                750         741.0
# 2     266.0      2296      800.0     11.0                806         811.0
# 3     258.0      2342      748.0      8.0                805         756.0
# 4     199.0      1448      254.0      5.0                320         259.0
#
#    ARRIVAL_DELAY  DIVERTED  CANCELLED CANCELLATION_REASON  AIR_SYSTEM_DELAY  \
# 0          -22.0         0          0                 NaN               NaN
# 1           -9.0         0          0                 NaN               NaN
# 2            5.0         0          0                 NaN               NaN
# 3           -9.0         0          0                 NaN               NaN
# 4          -21.0         0          0                 NaN               NaN
#
#    SECURITY_DELAY  AIRLINE_DELAY  LATE_AIRCRAFT_DELAY  WEATHER_DELAY  \
# 0             NaN            NaN                  NaN            NaN
# 1             NaN            NaN                  NaN            NaN
# 2             NaN            NaN                  NaN            NaN
# 3             NaN            NaN                  NaN            NaN
# 4             NaN            NaN                  NaN            NaN
#
#              AIRLINE_NAME                          ORIGIN_AIRPORT_NAME  \
# 0    Alaska Airlines Inc.  Ted Stevens Anchorage International Airport
# 1  American Airlines Inc.            Los Angeles International Airport
# 2         US Airways Inc.          San Francisco International Airport
# 3  American Airlines Inc.            Los Angeles International Airport
# 4    Alaska Airlines Inc.         Seattle-Tacoma International Airport
#
#      ORIGIN_CITY ORIGIN_STATE  ORIGIN_LAT  ORIGIN_LON  \
# 0      Anchorage           AK    61.17432  -149.99619
# 1    Los Angeles           CA    33.94254  -118.40807
# 2  San Francisco           CA    37.61900  -122.37484
# 3    Los Angeles           CA    33.94254  -118.40807
# 4        Seattle           WA    47.44898  -122.30931
#
#                              DEST_AIRPORT_NAME        DEST_CITY DEST_STATE  \
# 0         Seattle-Tacoma International Airport          Seattle         WA
# 1             Palm Beach International Airport  West Palm Beach         FL
# 2      Charlotte Douglas International Airport        Charlotte         NC
# 3                  Miami International Airport            Miami         FL
# 4  Ted Stevens Anchorage International Airport        Anchorage         AK
#
#    DEST_LAT   DEST_LON
# 0  47.44898 -122.30931
# 1  26.68316  -80.09559
# 2  35.21401  -80.94313
# 3  25.79325  -80.29056
# 4  61.17432 -149.99619

# %% [markdown]
# # Transformação
#
# 2. Remoção de colunas sem valor preditivo
# 3. Remoção de voos cancelados
# 4. Tratamento de NaN nas causas de atraso
# 5. Remoção de registros sem DEPARTURE_DELAY
# 6. Tratamento de NaN nas colunas de join
# 7. Feature engineering

# %% [markdown]
# ## Remoção de colunas sem valor preditivo
#
# - **YEAR**: constante (2015), variância zero
# - **TAIL_NUMBER**: identificador da aeronave (4.897 valores únicos), sem valor preditivo
# - **FLIGHT_NUMBER**: número do voo (6.952 valores únicos), sem valor preditivo
# - **AIRLINE_NAME**: identificador de nome da linha aerea.
# - **TAXI_OUT**:
# - **WHEELS_OFF**:
# - **AIR_TIME**:
# - **WHEELS_ON**:
# - **TAXI_IN**:
# - **ORIGIN_AIRPORT_NAME**:
# - **DEST_AIRPORT_NAME**:

# %%
flights = flights.drop(columns=["YEAR", "AIRLINE_NAME", "FLIGHT_NUMBER", "TAIL_NUMBER", "TAXI_OUT", "WHEELS_OFF", "AIR_TIME", "WHEELS_ON", "TAXI_IN", "ORIGIN_AIRPORT_NAME", "DEST_AIRPORT_NAME"])
print(f"Shape após drop de colunas: {flights.shape}")

print(flights.head(10))
# Out:
# Shape após drop de colunas: (5819079, 31)
#    MONTH  DAY  DAY_OF_WEEK AIRLINE ORIGIN_AIRPORT DESTINATION_AIRPORT  \
# 0      1    1            4      AS            ANC                 SEA
# 1      1    1            4      AA            LAX                 PBI
# 2      1    1            4      US            SFO                 CLT
# 3      1    1            4      AA            LAX                 MIA
# 4      1    1            4      AS            SEA                 ANC
# 5      1    1            4      DL            SFO                 MSP
# 6      1    1            4      NK            LAS                 MSP
# 7      1    1            4      US            LAX                 CLT
# 8      1    1            4      AA            SFO                 DFW
# 9      1    1            4      DL            LAS                 ATL
#
#    SCHEDULED_DEPARTURE  DEPARTURE_TIME  DEPARTURE_DELAY  SCHEDULED_TIME  \
# 0                    5          2354.0            -11.0           205.0
# 1                   10             2.0             -8.0           280.0
# 2                   20            18.0             -2.0           286.0
# 3                   20            15.0             -5.0           285.0
# 4                   25            24.0             -1.0           235.0
# 5                   25            20.0             -5.0           217.0
# 6                   25            19.0             -6.0           181.0
# 7                   30            44.0             14.0           273.0
# 8                   30            19.0            -11.0           195.0
# 9                   30            33.0              3.0           221.0
#
#    ELAPSED_TIME  DISTANCE  SCHEDULED_ARRIVAL  ARRIVAL_TIME  ARRIVAL_DELAY  \
# 0         194.0      1448                430         408.0          -22.0
# 1         279.0      2330                750         741.0           -9.0
# 2         293.0      2296                806         811.0            5.0
# 3         281.0      2342                805         756.0           -9.0
# 4         215.0      1448                320         259.0          -21.0
# 5         230.0      1589                602         610.0            8.0
# 6         170.0      1299                526         509.0          -17.0
# 7         249.0      2125                803         753.0          -10.0
# 8         193.0      1464                545         532.0          -13.0
# 9         203.0      1747                711         656.0          -15.0
#
#    DIVERTED  CANCELLED CANCELLATION_REASON  AIR_SYSTEM_DELAY  SECURITY_DELAY  \
# 0         0          0                 NaN               NaN             NaN
# 1         0          0                 NaN               NaN             NaN
# 2         0          0                 NaN               NaN             NaN
# 3         0          0                 NaN               NaN             NaN
# 4         0          0                 NaN               NaN             NaN
# 5         0          0                 NaN               NaN             NaN
# 6         0          0                 NaN               NaN             NaN
# 7         0          0                 NaN               NaN             NaN
# 8         0          0                 NaN               NaN             NaN
# 9         0          0                 NaN               NaN             NaN
#
#    AIRLINE_DELAY  LATE_AIRCRAFT_DELAY  WEATHER_DELAY    ORIGIN_CITY  \
# 0            NaN                  NaN            NaN      Anchorage
# 1            NaN                  NaN            NaN    Los Angeles
# 2            NaN                  NaN            NaN  San Francisco
# 3            NaN                  NaN            NaN    Los Angeles
# 4            NaN                  NaN            NaN        Seattle
# 5            NaN                  NaN            NaN  San Francisco
# 6            NaN                  NaN            NaN      Las Vegas
# 7            NaN                  NaN            NaN    Los Angeles
# 8            NaN                  NaN            NaN  San Francisco
# 9            NaN                  NaN            NaN      Las Vegas
#
#   ORIGIN_STATE  ORIGIN_LAT  ORIGIN_LON          DEST_CITY DEST_STATE  \
# 0           AK    61.17432  -149.99619            Seattle         WA
# 1           CA    33.94254  -118.40807    West Palm Beach         FL
# 2           CA    37.61900  -122.37484          Charlotte         NC
# 3           CA    33.94254  -118.40807              Miami         FL
# 4           WA    47.44898  -122.30931          Anchorage         AK
# 5           CA    37.61900  -122.37484        Minneapolis         MN
# 6           NV    36.08036  -115.15233        Minneapolis         MN
# 7           CA    33.94254  -118.40807          Charlotte         NC
# 8           CA    37.61900  -122.37484  Dallas-Fort Worth         TX
# 9           NV    36.08036  -115.15233            Atlanta         GA
#
#    DEST_LAT   DEST_LON
# 0  47.44898 -122.30931
# 1  26.68316  -80.09559
# 2  35.21401  -80.94313
# 3  25.79325  -80.29056
# 4  61.17432 -149.99619
# 5  44.88055  -93.21692
# 6  44.88055  -93.21692
# 7  35.21401  -80.94313
# 8  32.89595  -97.03720
# 9  33.64044  -84.42694

# %% [markdown]
# ## Remoção de voos cancelados
#
# Voos cancelados **não são voos atrasados** — são uma categoria diferente. Mantê-los confundiria a modelagem de atrasos, pois não possuem DEPARTURE_DELAY real.
#
# Após a remoção, as colunas `CANCELLED` (sempre 0) e `CANCELLATION_REASON` (sempre NaN) tornam-se constantes e também são removidas.

# %%
n_before = len(flights)
n_cancelled = flights['CANCELLED'].sum()
flights = flights.query("CANCELLED == 0").drop(columns=["CANCELLED", "CANCELLATION_REASON"])
print(f"Voos cancelados removidos: {n_cancelled:,}")
print(f"Shape após remoção: {flights.shape}")
# Out:
# Voos cancelados removidos: 89,884
# Shape após remoção: (5729195, 29)

# %% [markdown]
# ## Tratamento de colunas de causa de atraso
#
# As 5 colunas de causa (`AIR_SYSTEM_DELAY`, `SECURITY_DELAY`, `AIRLINE_DELAY`, `LATE_AIRCRAFT_DELAY`, `WEATHER_DELAY`) possuem ~82% de NaN **por design** — só são preenchidas quando o voo é atrasado.
#
# Um NaN nestas colunas significa **"sem atraso desta causa"**, não dado faltante. A imputação correta é com **0**.

# %%
delay_cause_cols = ['AIR_SYSTEM_DELAY', 'SECURITY_DELAY', 'AIRLINE_DELAY',
                    'LATE_AIRCRAFT_DELAY', 'WEATHER_DELAY']

print("NaN antes da imputação:")
print(flights[delay_cause_cols].isnull().sum().to_string())

flights[delay_cause_cols] = flights[delay_cause_cols].fillna(0)

print("\nNaN após imputação:")
print(flights[delay_cause_cols].isnull().sum().to_string())
# Out:
# NaN antes da imputação:
# AIR_SYSTEM_DELAY       4665756
# SECURITY_DELAY         4665756
# AIRLINE_DELAY          4665756
# LATE_AIRCRAFT_DELAY    4665756
# WEATHER_DELAY          4665756
#
# NaN após imputação:
# AIR_SYSTEM_DELAY       0
# SECURITY_DELAY         0
# AIRLINE_DELAY          0
# LATE_AIRCRAFT_DELAY    0
# WEATHER_DELAY          0

# %% [markdown]
# ## Remoção de registros sem DEPARTURE_DELAY
#
# Cerca de 1,5% dos registros não possuem `DEPARTURE_DELAY` — são dados operacionais genuinamente faltantes (voos desviados, falhas de registro). Sem esta informação, não é possível modelar o atraso.

# %%
n_before = len(flights)
flights = flights.dropna(subset=["DEPARTURE_DELAY"])
n_after = len(flights)
print(f"Registros removidos: {n_before - n_after:,}")
print(f"Registros retidos: {n_after:,} ({n_after/n_before*100:.1f}%)")
print(f"Shape: {flights.shape}")
# Out:
# Registros removidos: 0
# Registros retidos: 5,729,195 (100.0%)
# Shape: (5729195, 29)

# %% [markdown]
# ## Feature Engineering
#
# Variáveis derivadas para a modelagem:
#
# | Feature | Derivação | Justificativa |
# |---------|-----------|---------------|
# | `DEP_HOUR` | `SCHEDULED_DEPARTURE // 100` | Hora de partida agrupada — padrão de atraso varia ao longo do dia |
# | `SEASON` | Mapeamento de MONTH → 1-4 | Sazonalidade (inverno/primavera/verão/outono) |
# | `IS_WEEKEND` | `DAY_OF_WEEK >= 6` | Padrão de tráfego diferente em fins de semana |
# | `IS_SHORT_DISTANCE` | `DISTANCE <= 373` (Q1) | Voos regionais curtos (~25% dos voos) |
# | `IS_LONG_DISTANCE` | `DISTANCE >= 1066` (Q3) | Voos de longa distância (~25% dos voos) |
# | `IS_MORNING` | `DEP_HOUR` entre 5–11 | Período matutino (~42% dos voos) |
# | `IS_AFTERNOON` | `DEP_HOUR` entre 12–17 | Período vespertino (~38% dos voos) |
# | `IS_NIGHT` | `DEP_HOUR` fora de 5–17 | Período noturno (~20% dos voos) |
# | `IS_HOLIDAY` | Janela de 3 dias em torno de feriados federais EUA 2015 | Captura efeito de viagem em feriados |
# | `IS_DELAYED` | `DEPARTURE_DELAY > 15` | Target binário para classificação (limiar FAA de 15 min) |

# %%
from datetime import date, timedelta

# DEP_HOUR
flights['DEP_HOUR'] = flights['SCHEDULED_DEPARTURE'] // 100

# SEASON
season_map = {12: 1, 1: 1, 2: 1, 3: 2, 4: 2, 5: 2, 6: 3, 7: 3, 8: 3, 9: 4, 10: 4, 11: 4}
flights['SEASON'] = flights['MONTH'].map(season_map)

# IS_WEEKEND
flights['IS_WEEKEND'] = (flights['DAY_OF_WEEK'] >= 6).astype(int)

# IS_SHORT_DISTANCE / IS_LONG_DISTANCE (quartis Q1=373, Q3=1066)
flights['IS_SHORT_DISTANCE'] = (flights['DISTANCE'] <= 373).astype(int)
flights['IS_LONG_DISTANCE'] = (flights['DISTANCE'] >= 1066).astype(int)

# IS_MORNING / IS_AFTERNOON / IS_NIGHT
flights['IS_MORNING'] = flights['DEP_HOUR'].between(5, 11).astype(int)
flights['IS_AFTERNOON'] = flights['DEP_HOUR'].between(12, 17).astype(int)
flights['IS_NIGHT'] = (~flights['DEP_HOUR'].between(5, 17)).astype(int)

# IS_HOLIDAY (feriados federais EUA 2015 + véspera + dia seguinte)
federal_holidays_2015 = [
    date(2015, 1, 1),    # New Year's Day
    date(2015, 1, 19),   # MLK Day
    date(2015, 2, 16),   # Presidents' Day
    date(2015, 5, 25),   # Memorial Day
    date(2015, 7, 3),    # Independence Day (observed)
    date(2015, 7, 4),    # Independence Day
    date(2015, 9, 7),    # Labor Day
    date(2015, 10, 12),  # Columbus Day
    date(2015, 11, 11),  # Veterans Day
    date(2015, 11, 26),  # Thanksgiving
    date(2015, 12, 25),  # Christmas
]
holiday_dates = set()
for h in federal_holidays_2015:
    for delta in [-1, 0, 1]:
        d = h + timedelta(days=delta)
        holiday_dates.add((d.month, d.day))

flights['IS_HOLIDAY'] = pd.Series(
    list(zip(flights['MONTH'], flights['DAY']))
).isin(holiday_dates).astype(int).values

# IS_DELAYED (target)
flights['IS_DELAYED'] = (flights['DEPARTURE_DELAY'] > 15).astype(int)

# Verificação
print("Features criadas:")
print(flights[['MONTH', 'SEASON', 'DAY_OF_WEEK', 'IS_WEEKEND',
               'SCHEDULED_DEPARTURE', 'DEP_HOUR', 'IS_MORNING', 'IS_AFTERNOON', 'IS_NIGHT',
               'DISTANCE', 'IS_SHORT_DISTANCE', 'IS_LONG_DISTANCE',
               'IS_HOLIDAY', 'DEPARTURE_DELAY', 'IS_DELAYED']].head(10))

print(f"\nDistribuição IS_DELAYED:")
balance = flights['IS_DELAYED'].value_counts(normalize=True) * 100
print(f"  Pontual (0): {balance[0]:.1f}%")
print(f"  Atrasado (1): {balance[1]:.1f}%")

print(f"\nDistribuição das novas features:")
for col in ['IS_SHORT_DISTANCE', 'IS_LONG_DISTANCE', 'IS_MORNING', 'IS_AFTERNOON', 'IS_NIGHT', 'IS_HOLIDAY']:
    pct = flights[col].mean() * 100
    print(f"  {col}: {pct:.1f}%")
# Out:
# Features criadas:
#    MONTH  SEASON  DAY_OF_WEEK  IS_WEEKEND  SCHEDULED_DEPARTURE  DEP_HOUR  \
# 0      1       1            4           0                    5         0
# 1      1       1            4           0                   10         0
# 2      1       1            4           0                   20         0
# 3      1       1            4           0                   20         0
# 4      1       1            4           0                   25         0
# 5      1       1            4           0                   25         0
# 6      1       1            4           0                   25         0
# 7      1       1            4           0                   30         0
# 8      1       1            4           0                   30         0
# 9      1       1            4           0                   30         0
#
#    IS_MORNING  IS_AFTERNOON  IS_NIGHT  DISTANCE  IS_SHORT_DISTANCE  \
# 0           0             0         1      1448                  0
# 1           0             0         1      2330                  0
# 2           0             0         1      2296                  0
# 3           0             0         1      2342                  0
# 4           0             0         1      1448                  0
# 5           0             0         1      1589                  0
# 6           0             0         1      1299                  0
# 7           0             0         1      2125                  0
# 8           0             0         1      1464                  0
# 9           0             0         1      1747                  0
#
#    IS_LONG_DISTANCE  IS_HOLIDAY  DEPARTURE_DELAY  IS_DELAYED
# 0                 1           1            -11.0           0
# 1                 1           1             -8.0           0
# 2                 1           1             -2.0           0
# 3                 1           1             -5.0           0
# 4                 1           1             -1.0           0
# 5                 1           1             -5.0           0
# 6                 1           1             -6.0           0
# 7                 1           1             14.0           0
# 8                 1           1            -11.0           0
# 9                 1           1              3.0           0
#
# Distribuição IS_DELAYED:
#   Pontual (0): 82.3%
#   Atrasado (1): 17.7%
#
# Distribuição das novas features:
#   IS_SHORT_DISTANCE: 25.2%
#   IS_LONG_DISTANCE: 25.0%
#   IS_MORNING: 41.0%
#   IS_AFTERNOON: 36.8%
#   IS_NIGHT: 22.2%
#   IS_HOLIDAY: 8.0%

# %% [markdown]
# ## Verificação final
#
# Conferir shape, tipos e ausência de nulls em colunas críticas antes da exportação.

# %%
print(f"Shape final: {flights.shape}")
print(f"\nColunas: {list(flights.columns)}")
print(f"\nValores ausentes em colunas críticas:")
critical_cols = ['DEPARTURE_DELAY', 'IS_DELAYED', 'MONTH', 'DAY_OF_WEEK',
                 'DEP_HOUR', 'SEASON', 'IS_WEEKEND', 'DISTANCE', 'AIRLINE',
                 'IS_SHORT_DISTANCE', 'IS_LONG_DISTANCE',
                 'IS_MORNING', 'IS_AFTERNOON', 'IS_NIGHT', 'IS_HOLIDAY']
print(flights[critical_cols].isnull().sum().to_string())
print(f"\nDescrição do dataset limpo:")
flights.describe()
# Out:
# Shape final: (5729195, 39)
#
# Colunas: ['MONTH', 'DAY', 'DAY_OF_WEEK', 'AIRLINE', 'ORIGIN_AIRPORT', 'DESTINATION_AIRPORT', 'SCHEDULED_DEPARTURE', 'DEPARTURE_TIME', 'DEPARTURE_DELAY', 'SCHEDULED_TIME', 'ELAPSED_TIME', 'DISTANCE', 'SCHEDULED_ARRIVAL', 'ARRIVAL_TIME', 'ARRIVAL_DELAY', 'DIVERTED', 'AIR_SYSTEM_DELAY', 'SECURITY_DELAY', 'AIRLINE_DELAY', 'LATE_AIRCRAFT_DELAY', 'WEATHER_DELAY', 'ORIGIN_CITY', 'ORIGIN_STATE', 'ORIGIN_LAT', 'ORIGIN_LON', 'DEST_CITY', 'DEST_STATE', 'DEST_LAT', 'DEST_LON', 'DEP_HOUR', 'SEASON', 'IS_WEEKEND', 'IS_SHORT_DISTANCE', 'IS_LONG_DISTANCE', 'IS_MORNING', 'IS_AFTERNOON', 'IS_NIGHT', 'IS_HOLIDAY', 'IS_DELAYED']
#
# Valores ausentes em colunas críticas:
# DEPARTURE_DELAY      0
# IS_DELAYED           0
# MONTH                0
# DAY_OF_WEEK          0
# DEP_HOUR             0
# SEASON               0
# IS_WEEKEND           0
# DISTANCE             0
# AIRLINE              0
# IS_SHORT_DISTANCE    0
# IS_LONG_DISTANCE     0
# IS_MORNING           0
# IS_AFTERNOON         0
# IS_NIGHT             0
# IS_HOLIDAY           0
#
# Descrição do dataset limpo:
#               MONTH           DAY   DAY_OF_WEEK  SCHEDULED_DEPARTURE  \
# count  5.729195e+06  5.729195e+06  5.729195e+06         5.729195e+06
# mean   6.547562e+00  1.570848e+01  3.932479e+00         1.328890e+03
# std    3.397027e+00  8.774635e+00  1.986101e+00         4.834692e+02
# min    1.000000e+00  1.000000e+00  1.000000e+00         1.000000e+00
# 25%    4.000000e+00  8.000000e+00  2.000000e+00         9.160000e+02
# 50%    7.000000e+00  1.600000e+01  4.000000e+00         1.325000e+03
# 75%    9.000000e+00  2.300000e+01  6.000000e+00         1.730000e+03
# max    1.200000e+01  3.100000e+01  7.000000e+00         2.359000e+03
#
#        DEPARTURE_TIME  DEPARTURE_DELAY  SCHEDULED_TIME  ELAPSED_TIME  \
# count    5.729195e+06     5.729195e+06    5.729194e+06  5.714008e+06
# mean     1.335102e+03     9.338837e+00    1.419480e+02  1.370062e+02
# std      4.963902e+02     3.699246e+01    7.533501e+01  7.421107e+01
# min      1.000000e+00    -8.200000e+01    1.800000e+01  1.400000e+01
# 25%      9.210000e+02    -5.000000e+00    8.600000e+01  8.200000e+01
# 50%      1.330000e+03    -2.000000e+00    1.230000e+02  1.180000e+02
# 75%      1.740000e+03     7.000000e+00    1.740000e+02  1.680000e+02
# max      2.400000e+03     1.988000e+03    7.180000e+02  7.660000e+02
#
#            DISTANCE  SCHEDULED_ARRIVAL  ARRIVAL_TIME  ARRIVAL_DELAY  \
# count  5.729195e+06       5.729195e+06  5.726566e+06   5.714008e+06
# mean   8.248575e+02       1.493315e+03  1.476491e+03   4.407057e+00
# std    6.087992e+02       5.068360e+02  5.263197e+02   3.927130e+01
# min    3.100000e+01       1.000000e+00  1.000000e+00  -8.700000e+01
# 25%    3.730000e+02       1.110000e+03  1.059000e+03  -1.300000e+01
# 50%    6.500000e+02       1.520000e+03  1.512000e+03  -5.000000e+00
# 75%    1.066000e+03       1.917000e+03  1.917000e+03   8.000000e+00
# max    4.983000e+03       2.400000e+03  2.400000e+03   1.971000e+03
#
#            DIVERTED  AIR_SYSTEM_DELAY  SECURITY_DELAY  AIRLINE_DELAY  \
# count  5.729195e+06      5.729195e+06    5.729195e+06   5.729195e+06
# mean   2.650809e-03      2.502230e+00    1.413549e-02   3.521080e+00
# std    5.141772e-02      1.315419e+01    9.239484e-01   2.202142e+01
# min    0.000000e+00      0.000000e+00    0.000000e+00   0.000000e+00
# 25%    0.000000e+00      0.000000e+00    0.000000e+00   0.000000e+00
# 50%    0.000000e+00      0.000000e+00    0.000000e+00   0.000000e+00
# 75%    0.000000e+00      0.000000e+00    0.000000e+00   0.000000e+00
# max    1.000000e+00      1.134000e+03    5.730000e+02   1.971000e+03
#
#        LATE_AIRCRAFT_DELAY  WEATHER_DELAY    ORIGIN_LAT    ORIGIN_LON  \
# count         5.729195e+06   5.729195e+06  5.240912e+06  5.240912e+06
# mean          4.356970e+00   5.411289e-01  3.662367e+01 -9.556861e+01
# std           2.072791e+01   8.876031e+00  6.009700e+00  1.818742e+01
# min           0.000000e+00   0.000000e+00  1.348345e+01 -1.766460e+02
# 25%           0.000000e+00   0.000000e+00  3.289595e+01 -1.119778e+02
# 50%           0.000000e+00   0.000000e+00  3.724433e+01 -9.025803e+01
# 75%           0.000000e+00   0.000000e+00  4.078839e+01 -8.168786e+01
# max           1.331000e+03   1.211000e+03  7.128545e+01 -6.479856e+01
#
#            DEST_LAT      DEST_LON      DEP_HOUR        SEASON    IS_WEEKEND  \
# count  5.240900e+06  5.240900e+06  5.729195e+06  5.729195e+06  5.729195e+06
# mean   3.662358e+01 -9.556906e+01  1.302202e+01  2.523329e+00  2.611877e-01
# std    6.011084e+00  1.819061e+01  4.821875e+00  1.099398e+00  4.392820e-01
# min    1.348345e+01 -1.766460e+02  0.000000e+00  1.000000e+00  0.000000e+00
# 25%    3.289595e+01 -1.119778e+02  9.000000e+00  2.000000e+00  0.000000e+00
# 50%    3.724433e+01 -9.025803e+01  1.300000e+01  3.000000e+00  0.000000e+00
# 75%    4.078839e+01 -8.168786e+01  1.700000e+01  3.000000e+00  1.000000e+00
# max    7.128545e+01 -6.479856e+01  2.300000e+01  4.000000e+00  1.000000e+00
#
#        IS_SHORT_DISTANCE  IS_LONG_DISTANCE    IS_MORNING  IS_AFTERNOON  \
# count       5.729195e+06      5.729195e+06  5.729195e+06  5.729195e+06
# mean        2.515240e-01      2.500192e-01  4.097443e-01  3.681255e-01
# std         4.338890e-01      4.330238e-01  4.917865e-01  4.822957e-01
# min         0.000000e+00      0.000000e+00  0.000000e+00  0.000000e+00
# 25%         0.000000e+00      0.000000e+00  0.000000e+00  0.000000e+00
# 50%         0.000000e+00      0.000000e+00  0.000000e+00  0.000000e+00
# 75%         1.000000e+00      1.000000e+00  1.000000e+00  1.000000e+00
# max         1.000000e+00      1.000000e+00  1.000000e+00  1.000000e+00
#
#            IS_NIGHT    IS_HOLIDAY    IS_DELAYED
# count  5.729195e+06  5.729195e+06  5.729195e+06
# mean   2.221302e-01  7.992170e-02  1.774309e-01
# std    4.156782e-01  2.711720e-01  3.820330e-01
# min    0.000000e+00  0.000000e+00  0.000000e+00
# 25%    0.000000e+00  0.000000e+00  0.000000e+00
# 50%    0.000000e+00  0.000000e+00  0.000000e+00
# 75%    0.000000e+00  0.000000e+00  0.000000e+00
# max    1.000000e+00  1.000000e+00  1.000000e+00

# %% [markdown]
# ## Exportação em Parquet
#
# Salvamos o dataset limpo em formato Parquet (compressão snappy) para evitar reprocessamento nos notebooks seguintes. O Parquet preserva os tipos de dados e é significativamente mais rápido para leitura.

# %%
output_path = "../data/flights_clean.parquet"
flights.to_parquet(output_path, index=False)

# Verificação de roundtrip
df_check = pd.read_parquet(output_path)
assert df_check.shape == flights.shape, f"Shape mismatch: {df_check.shape} vs {flights.shape}"

import os
file_size_mb = os.path.getsize(output_path) / (1024 * 1024)
print(f"Arquivo salvo: {output_path}")
print(f"Tamanho: {file_size_mb:.1f} MB")
print(f"Shape verificada: {df_check.shape}")
print("\nExportação concluída com sucesso!")
# Out:
# Arquivo salvo: ../data/flights_clean.parquet
# Tamanho: 124.5 MB
# Shape verificada: (5729195, 39)
#
# Exportação concluída com sucesso!
